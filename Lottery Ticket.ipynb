# %%
import random 
dic={
'WR': 'IRINJALAKUDA',
'WN'  :'PATTAMBI',
'WO'  :'KAYAMKULAM',
'WP' : 'DIMALY',
'WR' :'THIRUR',
'WS':  'THIRUVANANTHAPURAM',
'WT'  :'CHERTHALA',
'WU':  'KANNUR',
'WV': 'KOZHIKKODE',
'WW': 'MANANTHAVADY',
'WX' : 'KOLLAM',
'WY' :'ERNAKULAM',
'WZ' :'NEYYATTINKARA'} 
d=random.choice(list(dic.keys()) )
#1st Prize Rs:7500000/-

print("1st Prize Rs:7500000/- \t") 
a=random.randint(1,3000000)
print(d,a,"(",dic[d],")") 
print()

#cons Prize 

print("cons Prize Rs:8000/- \t")
for x in dic.keys():
    print(x,a,"\t",end="")
print("\n")

#2st Prize Rs:5000000/-

print("2nd Prize Rs:5000000/- \t") 
b=random.randint(1,30000000)
d1=random.choice(list(dic.keys()) )
  
if  b != a : 
    print(d1,b,"(",dic[d1],")")
print()

#3st Prize Rs:1000000/-

print("3rd Prize Rs:1000000/- \t")
for x,y in dic.items():
    c=random.randint(1,3000000)
    if  c!=a or c!=b : 
       print(x,c,"(",y,")")
print()

print("FOR THE TICKETS ENDING WITH THE FOLLOWING NUMBERS:")

#4st Prize Rs:5000/-

print("4th Prize Rs :5000/- \t") 
for i in range(1,19):
    d=random.randint(0,10000)
    if d!=a or d!=b or d!=c:
      print(d,"\t",end="")
print("\n")
#5st Prize Rs:2000/-

print("5th Prize Rs:2000/- \t")
for i in range(1,11):
    e=random.randint(0,10000)
    if  e != a or e!=b or e!=c or e!=d:
         print(e,"\t",end="")
print("\n")

#6st Prize Rs:1000/-

print("6th Prize Rs:1000/- \t")
for i in range(1,15):
    f=random.randint(1000,10000)
    if f!=a or f!=b or f!=c or f!=d or f!=e:
        print(f,"\t",end="")
print("\n")


#7st Prize Rs:500/-

print("7th Prize Rs:500/- \t")
for i in range(1,83):
    g=random.randint(1,10000)
    if g!=a or g!=b or g!=c or g!=d or g != e or g!=d or g!=f:
        print(g,"\t",end="") 
print("\n")

#8st Prize Rs:100/-
print("8th Prize Rs:100/- \t")
for i in range(1,127):
    h=random.randint(1,10000)
    if  h!=a or h!=b or h!=c or h!=d or h != e or h!=d or h!=f or h!=g:
            print(h,"\t",end="")
# Out:
# 1st Prize Rs:7500000/-
# WR 1651761 ( THIRUR )
#
# cons Prize Rs:8000/-
# WR 1651761 	WN 1651761 	WO 1651761 	WP 1651761 	WS 1651761 	WT 1651761 	WU 1651761 	WV 1651761 	WW 1651761 	WX 1651761 	WY 1651761 	WZ 1651761
#
# 2nd Prize Rs:5000000/-
# WW 11197133 ( MANANTHAVADY )
#
# 3rd Prize Rs:1000000/-
# WR 1385270 ( THIRUR )
# WN 962552 ( PATTAMBI )
# WO 2715411 ( KAYAMKULAM )
# WP 412597 ( DIMALY )
# WS 676608 ( THIRUVANANTHAPURAM )
# WT 1981767 ( CHERTHALA )
# WU 1675906 ( KANNUR )
# WV 2274303 ( KOZHIKKODE )
# WW 1930840 ( MANANTHAVADY )
# WX 962850 ( KOLLAM )
# WY 356432 ( ERNAKULAM )
# WZ 110684 ( NEYYATTINKARA )
#
# FOR THE TICKETS ENDING WITH THE FOLLOWING NUMBERS:
# 4th Prize Rs :5000/-
# 7144 	3393 	4757 	1744 	9034 	5834 	4884 	4685 	783 	9942 	1798 	8840 	2922 	6816 	6156 	2788 	8073 	6661
#
# 5th Prize Rs:2000/-
# 6824 	1915 	7417 	5224 	7410 	8274 	9529 	2460 	4609 	7271
#
# 6th Prize Rs:1000/-
# ...
